# %% [markdown]
# **Emotion Detection**

# %% [markdown]
# *Importing Libraries*

# %%
import matplotlib.pyplot as plt
from glob import glob
import cv2
import random
import os
# %matplotlib inline

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Input, Dropout, Flatten, Conv2D
from tensorflow.keras.layers import BatchNormalization, Activation, MaxPooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import plot_model

from IPython.display import SVG, Image
import tensorflow as tf
print("Tensorflow version:", tf.__version__)
# Out:
# Tensorflow version: 2.19.0

# %% [markdown]
# *Exploring Dataset*

# %%
images = glob("**/train/**/**")
for i in range(9):
    image = random.choice(images)
    plt.figure(figsize=(12,12))
    plt.subplot(331+i)
    plt.imshow(cv2.imread(image));plt.axis('off')

# %% [markdown]
# *Preparing Data for Training*

# %%
img_size = 48
batch_size = 64

datagen_train = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

datagen_validation = ImageDataGenerator(rescale=1./255)

train_generator = datagen_train.flow_from_directory(
    "Emotion_Dataset/train/",
    target_size=(img_size, img_size),
    color_mode="grayscale",
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=True
)

validation_generator = datagen_validation.flow_from_directory(
    "Emotion_Dataset/test/",
    target_size=(img_size, img_size),
    color_mode="grayscale",
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=True
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# *Defining Model*

# %%
def Convolution(input_tensor, filters, kernel_size):
    x = Conv2D(filters = filters, kernel_size = kernel_size, padding = "same")(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size = (2,2))(x)
    x = Dropout(0.25)(x)
    
    return x

# %%
def Dense_f(input_tensor, nodes):
    x = Dense(nodes)(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.25)(x)
    
    return x

# %%
def model_fer(input_shape):
    inputs = Input(input_shape)
    conv_1 = Convolution(inputs,64,(3,3))
    conv_2 = Convolution(conv_1,128,(5,5))
    conv_3 = Convolution(conv_2,512,(3,3))
    conv_4 = Convolution(conv_3,512,(3,3))

    flatten = Flatten()(conv_4)
    
    dense_1 = Dense_f(flatten,256)
    dense_2 = Dense_f(dense_1,512)

    output  = Dense(7, activation="softmax")(dense_2)
    model  =  Model(inputs=[inputs],outputs = [output])
    opt = Adam(learning_rate=0.0005)
    
    model.compile(loss=['categorical_crossentropy'] , optimizer = opt , metrics =["accuracy"])

    return model

# %%
model = model_fer((48,48,1))
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 48, 48, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 48, 48, 64)     │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 48, 48, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 48, 48, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 24, 24, 128)    │       204,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 24, 24, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 24, 24, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 12, 12, 512)    │       590,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 12, 12, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 12, 12, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 6, 6, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 6, 6, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 6, 6, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 6, 6, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 6, 6, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 3, 3, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 3, 3, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4608)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     1,179,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 512)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │         3,591 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,478,727 (17.08 MB)
#  Trainable params: 4,474,759 (17.07 MB)
#  Non-trainable params: 3,968 (15.50 KB)

# %% [markdown]
# *Initializing the Model*

# %%
epochs = 30
steps_per_epoch = train_generator.n//train_generator.batch_size
validation_steps = validation_generator.n//validation_generator.batch_size

checkpoint = ModelCheckpoint("model.weights.h5", monitor  ='val_accuracy', save_weights_only = True, mode = 'max', verbose =1)
reducing_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, min_lr=0.00001)
callbacks = [checkpoint,reducing_lr]

# %% [markdown]
# **Traning the Model**

# %% [markdown]
# *The next cell takes time to complete*

# %%
history = model.fit(
x = train_generator,
steps_per_epoch = steps_per_epoch,
epochs = epochs,
validation_data = validation_generator,
validation_steps = validation_steps,
callbacks = callbacks)
# Out:
# c:\Users\jyoti\OneDrive\Desktop\Demo\Attendance\venv\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.2258 - loss: 2.0053
# Epoch 1: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1130s 3s/step - accuracy: 0.2259 - loss: 2.0051 - val_accuracy: 0.1717 - val_loss: 2.0366 - learning_rate: 5.0000e-04
# Epoch 2/30
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 13:05 2s/step - accuracy: 0.2969 - loss: 1.9508
# c:\Users\jyoti\OneDrive\Desktop\Demo\Attendance\venv\lib\site-packages\keras\src\trainers\epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 2: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 35s 75ms/step - accuracy: 0.2969 - loss: 1.9508 - val_accuracy: 0.1719 - val_loss: 2.0543 - learning_rate: 5.0000e-04
# Epoch 3/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 783ms/step - accuracy: 0.3080 - loss: 1.7510
# Epoch 3: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 369s 823ms/step - accuracy: 0.3080 - loss: 1.7509 - val_accuracy: 0.3933 - val_loss: 1.5357 - learning_rate: 5.0000e-04
# Epoch 4/30
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 4:05 548ms/step - accuracy: 0.3281 - loss: 1.6405
# Epoch 4: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 19s 41ms/step - accuracy: 0.3281 - loss: 1.6405 - val_accuracy: 0.3986 - val_loss: 1.5192 - learning_rate: 5.0000e-04
# Epoch 5/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 740ms/step - accuracy: 0.3802 - loss: 1.5918
# Epoch 5: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 374s 836ms/step - accuracy: 0.3802 - loss: 1.5917 - val_accuracy: 0.4838 - val_loss: 1.3368 - learning_rate: 5.0000e-04
# Epoch 6/30
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:24 1s/step - accuracy: 0.3906 - loss: 1.5690
# Epoch 6: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 29s 62ms/step - accuracy: 0.3906 - loss: 1.5690 - val_accuracy: 0.4830 - val_loss: 1.3361 - learning_rate: 5.0000e-04
# Epoch 7/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 808ms/step - accuracy: 0.4393 - loss: 1.4562
# Epoch 7: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 382s 851ms/step - accuracy: 0.4393 - loss: 1.4561 - val_accuracy: 0.5127 - val_loss: 1.2742 - learning_rate: 5.0000e-04
# Epoch 8/30
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 4:14 570ms/step - accuracy: 0.5312 - loss: 1.3334
# Epoch 8: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 19s 42ms/step - accuracy: 0.5312 - loss: 1.3334 - val_accuracy: 0.5120 - val_loss: 1.2807 - learning_rate: 5.0000e-04
# Epoch 9/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 844ms/step - accuracy: 0.4781 - loss: 1.3607
# Epoch 9: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 410s 915ms/step - accuracy: 0.4781 - loss: 1.3607 - val_accuracy: 0.5253 - val_loss: 1.2360 - learning_rate: 5.0000e-04
# Epoch 10/30
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 4:18 579ms/step - accuracy: 0.5469 - loss: 1.2518
# Epoch 10: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 23s 50ms/step - accuracy: 0.5469 - loss: 1.2518 - val_accuracy: 0.5265 - val_loss: 1.2333 - learning_rate: 5.0000e-04
# Epoch 11/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 740ms/step - accuracy: 0.4958 - loss: 1.3080
# Epoch 11: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 351s 781ms/step - accuracy: 0.4958 - loss: 1.3080 - val_accuracy: 0.5081 - val_loss: 1.2741 - learning_rate: 5.0000e-04
# Epoch 12/30
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 4:34 614ms/step - accuracy: 0.4844 - loss: 1.2972
# Epoch 12: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 19s 41ms/step - accuracy: 0.4844 - loss: 1.2972 - val_accuracy: 0.5084 - val_loss: 1.2700 - learning_rate: 5.0000e-04
# Epoch 13/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 695ms/step - accuracy: 0.5110 - loss: 1.2832
# Epoch 13: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 331s 738ms/step - accuracy: 0.5110 - loss: 1.2832 - val_accuracy: 0.5346 - val_loss: 1.1969 - learning_rate: 5.0000e-04
# Epoch 14/30
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 4:34 614ms/step - accuracy: 0.5469 - loss: 1.1166
# Epoch 14: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 20s 43ms/step - accuracy: 0.5469 - loss: 1.1166 - val_accuracy: 0.5399 - val_loss: 1.1778 - learning_rate: 5.0000e-04
# Epoch 15/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5227 - loss: 1.2506
# Epoch 15: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 601s 1s/step - accuracy: 0.5227 - loss: 1.2506 - val_accuracy: 0.5246 - val_loss: 1.2476 - learning_rate: 5.0000e-04
# Epoch 16/30
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 11:24 2s/step - accuracy: 0.5625 - loss: 1.1999
# Epoch 16: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 50s 109ms/step - accuracy: 0.5625 - loss: 1.1999 - val_accuracy: 0.5275 - val_loss: 1.2306 - learning_rate: 5.0000e-04
# Epoch 17/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5336 - loss: 1.2274
# Epoch 17: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 573s 1s/step - accuracy: 0.5336 - loss: 1.2274 - val_accuracy: 0.5858 - val_loss: 1.1120 - learning_rate: 5.0000e-04
# Epoch 18/30
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 1:55 257ms/step - accuracy: 0.4844 - loss: 1.0767
# Epoch 18: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.4844 - loss: 1.0767 - val_accuracy: 0.5840 - val_loss: 1.1124 - learning_rate: 5.0000e-04
# Epoch 19/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 0.5377 - loss: 1.2203
# Epoch 19: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 205s 457ms/step - accuracy: 0.5377 - loss: 1.2203 - val_accuracy: 0.5534 - val_loss: 1.1793 - learning_rate: 5.0000e-04
# Epoch 20/30
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 2:43 366ms/step - accuracy: 0.5625 - loss: 1.1935
# Epoch 20: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 16s 36ms/step - accuracy: 0.5625 - loss: 1.1935 - val_accuracy: 0.5559 - val_loss: 1.1709 - learning_rate: 5.0000e-04
# Epoch 21/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step - accuracy: 0.5519 - loss: 1.1774
# Epoch 21: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 228s 509ms/step - accuracy: 0.5520 - loss: 1.1773 - val_accuracy: 0.5992 - val_loss: 1.0498 - learning_rate: 5.0000e-05
# Epoch 22/30
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 3:01 405ms/step - accuracy: 0.5469 - loss: 1.3112
# Epoch 22: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 16s 35ms/step - accuracy: 0.5469 - loss: 1.3112 - val_accuracy: 0.5992 - val_loss: 1.0474 - learning_rate: 5.0000e-05
# Epoch 23/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 549ms/step - accuracy: 0.5554 - loss: 1.1626
# Epoch 23: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 263s 588ms/step - accuracy: 0.5554 - loss: 1.1626 - val_accuracy: 0.6025 - val_loss: 1.0448 - learning_rate: 5.0000e-05
# Epoch 24/30
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 3:15 438ms/step - accuracy: 0.5312 - loss: 1.1114
# Epoch 24: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 18s 40ms/step - accuracy: 0.5312 - loss: 1.1114 - val_accuracy: 0.6032 - val_loss: 1.0436 - learning_rate: 5.0000e-05
# Epoch 25/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - accuracy: 0.5676 - loss: 1.1337
# Epoch 25: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 259s 578ms/step - accuracy: 0.5676 - loss: 1.1337 - val_accuracy: 0.6027 - val_loss: 1.0345 - learning_rate: 5.0000e-05
# Epoch 26/30
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 4:20 584ms/step - accuracy: 0.5938 - loss: 1.2464
# Epoch 26: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 20s 44ms/step - accuracy: 0.5938 - loss: 1.2464 - val_accuracy: 0.6039 - val_loss: 1.0329 - learning_rate: 5.0000e-05
# Epoch 27/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 614ms/step - accuracy: 0.5640 - loss: 1.1404
# Epoch 27: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 297s 663ms/step - accuracy: 0.5640 - loss: 1.1404 - val_accuracy: 0.6087 - val_loss: 1.0294 - learning_rate: 5.0000e-05
# Epoch 28/30
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 4:26 596ms/step - accuracy: 0.6094 - loss: 1.0590
# Epoch 28: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 21s 47ms/step - accuracy: 0.6094 - loss: 1.0590 - val_accuracy: 0.6083 - val_loss: 1.0300 - learning_rate: 5.0000e-05
# Epoch 29/30
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 625ms/step - accuracy: 0.5694 - loss: 1.1356
# Epoch 29: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 302s 674ms/step - accuracy: 0.5694 - loss: 1.1356 - val_accuracy: 0.6169 - val_loss: 1.0142 - learning_rate: 5.0000e-05
# Epoch 30/30
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 4:25 593ms/step - accuracy: 0.5781 - loss: 1.0693
# Epoch 30: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 24s 52ms/step - accuracy: 0.5781 - loss: 1.0693 - val_accuracy: 0.6170 - val_loss: 1.0141 - learning_rate: 5.0000e-05

# %% [markdown]
# *Model Evaluation*

# %%
model.evaluate(validation_generator)
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 85s 753ms/step - accuracy: 0.6209 - loss: 1.0125
# [1.0142717361450195, 0.6170242428779602]

# %% [markdown]
# *Plotting Loss*

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.legend(['Train','Validation'],loc = 'upper left')
plt.subplots_adjust(top=1.0,bottom=0.0,right =0.95,left=0.0,hspace=0.25,wspace=0.35)

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.legend(['Train','Validation'],loc = 'upper left')
plt.subplots_adjust(top=1.0,bottom=0.0,right =0.95,left=0.0,hspace=0.25,wspace=0.35)

# %% [markdown]
# *Saving Model*

# %%
model.save("emotion_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
